# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\harsh\Downloads\profile.py"
with open(file_path) as file:
    exec(file.read())

# %%
df1=pd.read_hdf(r"C:\Users\harsh\OneDrive\.wdc\Desktop\Space Research\GMD\Data\fcc_database_v1.hdf5")
df1=df1.dropna()
df=df1.drop(columns=['SDEX', 'SDEY', 'SDEP', 'HRZ', 'DZMAX', 'SDX', 'SDY','SDZ','DateTime'])
df

# %%
cor_col = ['HMAEX', 'HMAEY' , 'EMAX' , 'HRX' , 'HRY' , 'DXMAX' ,'DYMAX']  
fet_col = [col for col in df.columns if col not in cor_col]

# %%
cor_mat = cor_matrix(f_dat=fet_col, 
                    y_dat=cor_col,
                    cor_dat=df, numeric_only=True)

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(cor_mat.abs(),annot=True, fmt='.2f', cbar_kws={'label':'Abs Correlation - abs(r)'})
plt.yticks() 
plt.show()
